# %% [markdown]
# TFG
#
# Este es el codigo del tfg de Borja Jimeno

# %%
import numpy as np
import math as m
import matplotlib.pyplot as plt
from scipy import special
from scipy.stats import norm
import re




plt.rcParams['font.size'] = 18

# %%
import uproot
file = uproot.open("results3.root")
file.keys()
# Out:
# ['gA112_6y_90_1.000000_2.000000_QFtamara_SI;1',
#  'gA112_6y_90_1.000000_2.000000_QFtamara_SDproton;1',
#  'gA112_6y_90_1.000000_2.000000_QFtamara_SDneutron;1',
#  'gA112_6y_90_1.000000_3.000000_QFtamara_SI;1',
#  'gA112_6y_90_1.000000_3.000000_QFtamara_SDproton;1',
#  'gA112_6y_90_1.000000_3.000000_QFtamara_SDneutron;1',
#  'gA112_6y_90_1.000000_4.000000_QFtamara_SI;1',
#  'gA112_6y_90_1.000000_4.000000_QFtamara_SDproton;1',
#  'gA112_6y_90_1.000000_4.000000_QFtamara_SDneutron;1',
#  'gA112_6y_90_1.000000_5.000000_QFtamara_SI;1',
#  'gA112_6y_90_1.000000_5.000000_QFtamara_SDproton;1',
#  'gA112_6y_90_1.000000_5.000000_QFtamara_SDneutron;1',
#  'gA112_6y_90_1.000000_6.000000_QFtamara_SI;1',
#  'gA112_6y_90_1.000000_6.000000_QFtamara_SDproton;1',
#  'gA112_6y_90_1.000000_6.000000_QFtamara_SDneutron;1',
#  'gA112_6y_90_2.000000_3.000000_QFtamara_SI;1',
#  'gA112_6y_90_2.000000_3.000000_QFtamara_SDproton;1',
#  'gA112_6y_90_2.000000_3.000000_QFtamara_SDneutron;1',
# ...

# %%
def carga_datos_hist(titulo):
    file = uproot.open("results_anod.root")
    file.keys()
    longitud=36*4
    datos=np.zeros((6,longitud))
    i=0
    for a in ("SDproton","SDneutron","SI"):
        graph = file[titulo+a]
        datos[2*i]=graph.member("fX")
        datos[2*i+1]=graph.member("fY")
        i=i+1
    return datos
     

Datos16_ALE=carga_datos_hist("gA112_6y_90_1.000000_6.000000_QFtamara_ANOD_")
Datos26_ALE=carga_datos_hist("gA112_6y_90_2.000000_6.000000_QFtamara_ANOD_")
Datos12_ALE=carga_datos_hist("gA112_6y_90_1.000000_2.000000_QFtamara_ANOD_")
Datos13_ALE=carga_datos_hist("gA112_6y_90_1.000000_3.000000_QFtamara_ANOD_")

for i in range (3):
    idx = np.argsort(Datos16_ALE[2*i])
    Datos16_ALE[2*i+1]= Datos16_ALE[2*i+1][idx]
    Datos26_ALE[2*i+1]= Datos26_ALE[2*i+1][idx]
    Datos12_ALE[2*i+1]= Datos12_ALE[2*i+1][idx]
    Datos13_ALE[2*i+1]= Datos13_ALE[2*i+1][idx]
    Datos16_ALE[2*i]= Datos16_ALE[2*i][idx]
    Datos26_ALE[2*i]= Datos26_ALE[2*i][idx]
    Datos12_ALE[2*i]= Datos12_ALE[2*i][idx]
    Datos13_ALE[2*i]= Datos13_ALE[2*i][idx]

# %%
import numpy as np


def carga_datos_hist(titulo):
    file = uproot.open("results3.root")
    file.keys()
    longitud=36*4
    datos=np.zeros((6,longitud))
    i=0
    for a in ("SDproton","SDneutron","SI"):
        graph = file[titulo+a]
        datos[2*i]=graph.member("fX")
        datos[2*i+1]=graph.member("fY")
        i=i+1
    return datos
     

Datos16=carga_datos_hist("gA112_6y_90_1.000000_6.000000_QFtamara_")
Datos26=carga_datos_hist("gA112_6y_90_2.000000_6.000000_QFtamara_")
Datos12=carga_datos_hist("gA112_6y_90_1.000000_2.000000_QFtamara_")
Datos13=carga_datos_hist("gA112_6y_90_1.000000_3.000000_QFtamara_")

for i in range (3):
    idx = np.argsort(Datos16[2*i])
    Datos16[2*i+1]= Datos16[2*i+1][idx]
    Datos26[2*i+1]= Datos26[2*i+1][idx]
    Datos12[2*i+1]= Datos12[2*i+1][idx]
    Datos13[2*i+1]= Datos13[2*i+1][idx]
    Datos16[2*i]= Datos16[2*i][idx]
    Datos26[2*i]= Datos26[2*i][idx]
    Datos12[2*i]= Datos12[2*i][idx]
    Datos13[2*i]= Datos13[2*i][idx]


i1=4
i2=i1+1

plt.figure(figsize=(14, 8))


ax = plt.subplot()

ax.plot(Datos16[i1],Datos16[i2],c='red',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$")
ax.plot(Datos26[i1],Datos26[i2],c='blue',label="$E_i=$"+f"{2}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$")
ax.plot(Datos12[i1],Datos12[i2],c='green',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{2}"+" $keV_{ee}$")
ax.plot(Datos13[i1],Datos13[i2],c='purple',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{3}"+" $keV_{ee}$")

ax.plot(Datos16_ALE[i1],Datos16_ALE[i2],c='red',linestyle='--',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$ (ALE)")
ax.plot(Datos26_ALE[i1],Datos26_ALE[i2],c='blue',linestyle='--',label="$E_i=$"+f"{2}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$ (ALE)")
ax.plot(Datos12_ALE[i1],Datos12_ALE[i2],c='green',linestyle='--',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{2}"+" $keV_{ee}$ (ALE)")
ax.plot(Datos13_ALE[i1],Datos13_ALE[i2],c='purple',linestyle='--',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{3}"+" $keV_{ee}$ (ALE)")



ax.legend(fontsize='x-small', markerscale=0.8, ncol=1)
ax.set_title(r'Plots de Exlusión - $\sigma_{SI}$  en función de $m_w$ (GeV)')
ax.set_ylabel(r'$\sigma_{SI}$ $(cm^2)$',fontsize=20)
ax.set_xlabel(r'$m_w$ (GeV)',fontsize=20)

ax.set_yscale("log")
ax.set_xscale("log")

y_sup=1e-36
y_inf=1e-43

ax.set_ylim(y_inf,y_sup)
ax.set_xlim(1,1000)

exp_min = int(np.floor(np.log10(y_inf)))   
exp_max = int(np.ceil(np.log10(y_sup)))    
exps = np.arange(exp_min, exp_max)     


all_ticks = []
for e in exps:
    decade = (np.arange(1, 10) * (10.0**e)).tolist()
    all_ticks.extend(decade)
all_ticks = np.array(all_ticks)

ax.set_yticks(all_ticks)                    

ax.grid(which='both', linestyle='-', alpha=0.2)

m=Datos16[i1]
s=Datos16[i2]

fichero = open("SI_ANAIS_16.txt", 'w')
# Guardamos la lista en el fichero
for i in range(len(m)):
    fichero.write(f"{m[i]} \t {s[i]} \n")

# Cerramos el fichero
fichero.close()

# %%
import numpy as np


def carga_datos_hist(titulo):
    file = uproot.open("results3_SD_ANOD_FALSE.root")
    file.keys()
    longitud=36*4
    datos=np.zeros((6,longitud))
    i=0
    for a in ("SDproton","SDneutron"):
        graph = file[titulo+a]
        datos[2*i]=graph.member("fX")
        datos[2*i+1]=graph.member("fY")
        i=i+1
    return datos
     

Datos16=carga_datos_hist("gA112_6y_90_1.000000_6.000000_QFtamara_")
Datos26=carga_datos_hist("gA112_6y_90_2.000000_6.000000_QFtamara_")
Datos12=carga_datos_hist("gA112_6y_90_1.000000_2.000000_QFtamara_")
Datos13=carga_datos_hist("gA112_6y_90_1.000000_3.000000_QFtamara_")

for i in range (3):
    idx = np.argsort(Datos16[2*i])
    Datos16[2*i+1]= Datos16[2*i+1][idx]
    Datos26[2*i+1]= Datos26[2*i+1][idx]
    Datos12[2*i+1]= Datos12[2*i+1][idx]
    Datos13[2*i+1]= Datos13[2*i+1][idx]
    Datos16[2*i]= Datos16[2*i][idx]
    Datos26[2*i]= Datos26[2*i][idx]
    Datos12[2*i]= Datos12[2*i][idx]
    Datos13[2*i]= Datos13[2*i][idx]


i1=0
i2=i1+1

plt.figure(figsize=(14, 8))


ax = plt.subplot()

ax.plot(Datos16[i1],Datos16[i2],c='red',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$")
ax.plot(Datos26[i1],Datos26[i2],c='blue',label="$E_i=$"+f"{2}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$")
ax.plot(Datos12[i1],Datos12[i2],c='green',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{2}"+" $keV_{ee}$")
ax.plot(Datos13[i1],Datos13[i2],c='purple',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{3}"+" $keV_{ee}$")

ax.plot(Datos16_ALE[i1],Datos16_ALE[i2],c='red',linestyle='--',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$ (ALE)")
ax.plot(Datos26_ALE[i1],Datos26_ALE[i2],c='blue',linestyle='--',label="$E_i=$"+f"{2}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$ (ALE)")
ax.plot(Datos12_ALE[i1],Datos12_ALE[i2],c='green',linestyle='--',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{2}"+" $keV_{ee}$ (ALE)")
ax.plot(Datos13_ALE[i1],Datos13_ALE[i2],c='purple',linestyle='--',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{3}"+" $keV_{ee}$ (ALE)")



ax.legend(fontsize='x-small', markerscale=0.8, ncol=1)
ax.set_title(r'Plots de Exlusión - $\sigma_{SD_p}$  en función de $m_w$ (GeV)')
ax.set_ylabel(r'$\sigma_{SD_p}$ $(cm^2)$',fontsize=20)
ax.set_xlabel(r'$m_w$ (GeV)',fontsize=20)

ax.set_yscale("log")
ax.set_xscale("log")

y_sup=1e-32
y_inf=1e-39

ax.set_ylim(y_inf,y_sup)
ax.set_xlim(1,1000)

exp_min = int(np.floor(np.log10(y_inf)))   
exp_max = int(np.ceil(np.log10(y_sup)))    
exps = np.arange(exp_min, exp_max)     


all_ticks = []
for e in exps:
    decade = (np.arange(1, 10) * (10.0**e)).tolist()
    all_ticks.extend(decade)
all_ticks = np.array(all_ticks)

ax.set_yticks(all_ticks)                    

ax.grid(which='both', linestyle='-', alpha=0.2)

m=Datos16[i1]
s=Datos16[i2]

fichero = open("SD_P_ANAIS_16.txt", 'w')
# Guardamos la lista en el fichero
for i in range(len(m)):
    fichero.write(f"{m[i]} \t {s[i]} \n")

# Cerramos el fichero
fichero.close()

# %%
import numpy as np


def carga_datos_hist(titulo):
    file = uproot.open("results3_SD_ANOD_FALSE.root")
    file.keys()
    longitud=36*4
    datos=np.zeros((6,longitud))
    i=0
    for a in ("SDproton","SDneutron"):
        graph = file[titulo+a]
        datos[2*i]=graph.member("fX")
        datos[2*i+1]=graph.member("fY")
        i=i+1
    return datos
     

Datos16=carga_datos_hist("gA112_6y_90_1.000000_6.000000_QFtamara_")
Datos26=carga_datos_hist("gA112_6y_90_2.000000_6.000000_QFtamara_")
Datos12=carga_datos_hist("gA112_6y_90_1.000000_2.000000_QFtamara_")
Datos13=carga_datos_hist("gA112_6y_90_1.000000_3.000000_QFtamara_")

for i in range (3):
    idx = np.argsort(Datos16[2*i])
    Datos16[2*i+1]= Datos16[2*i+1][idx]
    Datos26[2*i+1]= Datos26[2*i+1][idx]
    Datos12[2*i+1]= Datos12[2*i+1][idx]
    Datos13[2*i+1]= Datos13[2*i+1][idx]
    Datos16[2*i]= Datos16[2*i][idx]
    Datos26[2*i]= Datos26[2*i][idx]
    Datos12[2*i]= Datos12[2*i][idx]
    Datos13[2*i]= Datos13[2*i][idx]


i1=2
i2=i1+1

plt.figure(figsize=(14, 8))


ax = plt.subplot()

ax.plot(Datos16[i1],Datos16[i2],c='red',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$")
ax.plot(Datos26[i1],Datos26[i2],c='blue',label="$E_i=$"+f"{2}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$")
ax.plot(Datos12[i1],Datos12[i2],c='green',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{2}"+" $keV_{ee}$")
ax.plot(Datos13[i1],Datos13[i2],c='purple',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{3}"+" $keV_{ee}$")

ax.plot(Datos16_ALE[i1],Datos16_ALE[i2],c='red',linestyle='--',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$ (ALE)")
ax.plot(Datos26_ALE[i1],Datos26_ALE[i2],c='blue',linestyle='--',label="$E_i=$"+f"{2}"+" $keV_{ee}$; $E_f=$"+f"{6}"+" $keV_{ee}$ (ALE)")
ax.plot(Datos12_ALE[i1],Datos12_ALE[i2],c='green',linestyle='--',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{2}"+" $keV_{ee}$ (ALE)")
ax.plot(Datos13_ALE[i1],Datos13_ALE[i2],c='purple',linestyle='--',label="$E_i=$"+f"{1}"+" $keV_{ee}$; $E_f=$"+f"{3}"+" $keV_{ee}$ (ALE)")



ax.legend(fontsize='x-small', markerscale=0.8, ncol=1)
ax.set_title(r'Plots de Exlusión - $\sigma_{SD_n}$  en función de $m_w$ (GeV)')
ax.set_ylabel(r'$\sigma_{SD_n}$ $(cm^2)$',fontsize=20)
ax.set_xlabel(r'$m_w$ (GeV)',fontsize=20)

ax.set_yscale("log")
ax.set_xscale("log")

y_sup=1e-30
y_inf=1e-38

ax.set_ylim(y_inf,y_sup)
ax.set_xlim(1,1000)

exp_min = int(np.floor(np.log10(y_inf)))   
exp_max = int(np.ceil(np.log10(y_sup)))    
exps = np.arange(exp_min, exp_max)     


all_ticks = []
for e in exps:
    decade = (np.arange(1, 10) * (10.0**e)).tolist()
    all_ticks.extend(decade)
all_ticks = np.array(all_ticks)

ax.set_yticks(all_ticks)                    

ax.grid(which='both', linestyle='-', alpha=0.2)

m=Datos16[i1]
s=Datos16[i2]

fichero = open("SD_N_ANAIS_16.txt", 'w')
# Guardamos la lista en el fichero
for i in range(len(m)):
    fichero.write(f"{m[i]} \t {s[i]} \n")

# Cerramos el fichero
fichero.close()
