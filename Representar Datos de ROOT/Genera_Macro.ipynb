# %% [markdown]
# # Creamos el archivo para la macro con el intervalo deseado

# %%
import numpy as np
import math as m
import matplotlib.pyplot as plt
from scipy import special
from scipy.stats import norm
import re




plt.rcParams['font.size'] = 18

einf=1
esup=6
window=1
step=0.5

modes=[0,1,2]

list_names=[]

i=einf
while i<esup:
    j=i+window
    while j<=esup:
        for k in modes:
            if(i%1!=0 or j%1!=0):
                list_names.append("./fitSimulMakeExclusion 90 "+f'{float(i):.1f}' + " " + f'{float(j):.1f}'+ " " + str(k))
        j=j+step
    i=i+step



            


print(list_names)

fichero = open("datos_guardados.txt", 'w')
# Guardamos la lista en el fichero
for linea in list_names:
    fichero.write(linea + "\n")

# Cerramos el fichero
fichero.close()
# Out:
# ['./fitSimulMakeExclusion 90 1.0 2.5 0', './fitSimulMakeExclusion 90 1.0 2.5 1', './fitSimulMakeExclusion 90 1.0 2.5 2', './fitSimulMakeExclusion 90 1.0 3.5 0', './fitSimulMakeExclusion 90 1.0 3.5 1', './fitSimulMakeExclusion 90 1.0 3.5 2', './fitSimulMakeExclusion 90 1.0 4.5 0', './fitSimulMakeExclusion 90 1.0 4.5 1', './fitSimulMakeExclusion 90 1.0 4.5 2', './fitSimulMakeExclusion 90 1.0 5.5 0', './fitSimulMakeExclusion 90 1.0 5.5 1', './fitSimulMakeExclusion 90 1.0 5.5 2', './fitSimulMakeExclusion 90 1.5 2.5 0', './fitSimulMakeExclusion 90 1.5 2.5 1', './fitSimulMakeExclusion 90 1.5 2.5 2', './fitSimulMakeExclusion 90 1.5 3.0 0', './fitSimulMakeExclusion 90 1.5 3.0 1', './fitSimulMakeExclusion 90 1.5 3.0 2', './fitSimulMakeExclusion 90 1.5 3.5 0', './fitSimulMakeExclusion 90 1.5 3.5 1', './fitSimulMakeExclusion 90 1.5 3.5 2', './fitSimulMakeExclusion 90 1.5 4.0 0', './fitSimulMakeExclusion 90 1.5 4.0 1', './fitSimulMakeExclusion 90 1.5 4.0 2', './fitSimulMakeExclusion 90 1.5 4.5 0', './fitSimulMakeExclusion 90 1.5 4.5 1', './fitSimulMakeExclusion 90 1.5 4.5 2', './fitSimulMakeExclusion 90 1.5 5.0 0', './fitSimulMakeExclusion 90 1.5 5.0 1', './fitSimulMakeExclusion 90 1.5 5.0 2', './fitSimulMakeExclusion 90 1.5 5.5 0', './fitSimulMakeExclusion 90 1.5 5.5 1', './fitSimulMakeExclusion 90 1.5 5.5 2', './fitSimulMakeExclusion 90 1.5 6.0 0', './fitSimulMakeExclusion 90 1.5 6.0 1', './fitSimulMakeExclusion 90 1.5 6.0 2', './fitSimulMakeExclusion 90 2.0 3.5 0', './fitSimulMakeExclusion 90 2.0 3.5 1', './fitSimulMakeExclusion 90 2.0 3.5 2', './fitSimulMakeExclusion 90 2.0 4.5 0', './fitSimulMakeExclusion 90 2.0 4.5 1', './fitSimulMakeExclusion 90 2.0 4.5 2', './fitSimulMakeExclusion 90 2.0 5.5 0', './fitSimulMakeExclusion 90 2.0 5.5 1', './fitSimulMakeExclusion 90 2.0 5.5 2', './fitSimulMakeExclusion 90 2.5 3.5 0', './fitSimulMakeExclusion 90 2.5 3.5 1', './fitSimulMakeExclusion 90 2.5 3.5 2', './fitSimulMakeExclusion 90 2.5 4.0 0', './fitSimulMakeExclusion 90 2.5 4.0 1', './fitSimulMakeExclusion 90 2.5 4.0 2', './fitSimulMakeExclusion 90 2.5 4.5 0', './fitSimulMakeExclusion 90 2.5 4.5 1', './fitSimulMakeExclusion 90 2.5 4.5 2', './fitSimulMakeExclusion 90 2.5 5.0 0', './fitSimulMakeExclusion 90 2.5 5.0 1', './fitSimulMakeExclusion 90 2.5 5.0 2', './fitSimulMakeExclusion 90 2.5 5.5 0', './fitSimulMakeExclusion 90 2.5 5.5 1', './fitSimulMakeExclusion 90 2.5 5.5 2', './fitSimulMakeExclusion 90 2.5 6.0 0', './fitSimulMakeExclusion 90 2.5 6.0 1', './fitSimulMakeExclusion 90 2.5 6.0 2', './fitSimulMakeExclusion 90 3.0 4.5 0', './fitSimulMakeExclusion 90 3.0 4.5 1', './fitSimulMakeExclusion 90 3.0 4.5 2', './fitSimulMakeExclusion 90 3.0 5.5 0', './fitSimulMakeExclusion 90 3.0 5.5 1', './fitSimulMakeExclusion 90 3.0 5.5 2', './fitSimulMakeExclusion 90 3.5 4.5 0', './fitSimulMakeExclusion 90 3.5 4.5 1', './fitSimulMakeExclusion 90 3.5 4.5 2', './fitSimulMakeExclusion 90 3.5 5.0 0', './fitSimulMakeExclusion 90 3.5 5.0 1', './fitSimulMakeExclusion 90 3.5 5.0 2', './fitSimulMakeExclusion 90 3.5 5.5 0', './fitSimulMakeExclusion 90 3.5 5.5 1', './fitSimulMakeExclusion 90 3.5 5.5 2', './fitSimulMakeExclusion 90 3.5 6.0 0', './fitSimulMakeExclusion 90 3.5 6.0 1', './fitSimulMakeExclusion 90 3.5 6.0 2', './fitSimulMakeExclusion 90 4.0 5.5 0', './fitSimulMakeExclusion 90 4.0 5.5 1', './fitSimulMakeExclusion 90 4.0 5.5 2', './fitSimulMakeExclusion 90 4.5 5.5 0', './fitSimulMakeExclusion 90 4.5 5.5 1', './fitSimulMakeExclusion 90 4.5 5.5 2', './fitSimulMakeExclusion 90 4.5 6.0 0', './fitSimulMakeExclusion 90 4.5 6.0 1', './fitSimulMakeExclusion 90 4.5 6.0 2']
